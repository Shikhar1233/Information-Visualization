# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("document.csv")

# %%
df.head()
# Out:
#      Months  Groceries  Electricity Bill  Cook pay  Water bill  Gas bill  \
# 0  Jannuary       4000              1000      3000        2000      4567
# 1   Febuary       5000              2000      2000        2000       234
# 2     March       3000              3000      3000        2000      4563
# 3     April       2000              4000      4000        3000       678
# 4       May       1000              3000      5000         340       980
#
#     Rent
# 0  20000
# 1  20030
# 2  30455
# 3  45609
# 4  45634

# %%
df=df.dropna()

# %%
df.head()
# Out:
#      Months  Groceries  Electricity Bill  Cook pay  Water bill  Gas bill  \
# 0  Jannuary       4000              1000      3000        2000      4567
# 1   Febuary       5000              2000      2000        2000       234
# 2     March       3000              3000      3000        2000      4563
# 3     April       2000              4000      4000        3000       678
# 4       May       1000              3000      5000         340       980
#
#     Rent
# 0  20000
# 1  20030
# 2  30455
# 3  45609
# 4  45634

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Months            7 non-null      object
#  1   Groceries         7 non-null      int64
#  2   Electricity Bill  7 non-null      int64
#  3   Cook pay          7 non-null      int64
#  4   Water bill        7 non-null      int64
#  5   Gas bill          7 non-null      int64
#  6   Rent              7 non-null      int64
# dtypes: int64(6), object(1)
# memory usage: 520.0+ bytes

# %%
df.isnull().sum()
# Out:
# Months              0
# Groceries           0
# Electricity Bill    0
# Cook pay            0
# Water bill          0
# Gas bill            0
# Rent                0
# dtype: int64

# %%
plt.figure(figsize=(20,20))
df.plot(kind="bar",x="Months",y="Rent",color="red")
# Out:
# <Axes: xlabel='Months'>

# %%
df.groupby(['Months']).sum().plot(kind="pie",y="Cook pay",autopct='%1.0f%%',legend=False)
# Out:
# <Axes: ylabel='Cook pay'>
